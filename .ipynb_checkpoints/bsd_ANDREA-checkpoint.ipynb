# %%
# %load_ext autoreload
# %autoreload 2

from Classes_and_functions import imports

from Classes_and_functions.Dataloader import load_datasets
from Classes_and_functions.Dataloader import load_real_datasets
from Classes_and_functions.Dataloader import functions

from Classes_and_functions.Model import model_classes

from Classes_and_functions.Training import train_epochs
from Classes_and_functions.Training import functions as training_functions
from Classes_and_functions.Training import visualize_results

from Classes_and_functions.Real import functions as real_functions
from Classes_and_functions.Real import load_only_real
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
writer = imports.SummaryWriter()

# %% [markdown]
# ## Dataset

# %%
train_datapath = "Datasets/Training_set"
val_datapath = "Datasets/Validation_set"
test_datapath = "Datasets/Test_set"

# %%
train_data = load_datasets.SonarDescriptorDatasetFull(train_datapath, None)
val_data = load_datasets.SonarDescriptorDatasetFull(val_datapath, train_data)
test_data = load_datasets.SonarDescriptorDatasetFull(test_datapath, train_data)

# %%
print("Training: " + str(len(train_data.imgs)))
print("Validation: " + str(len(val_data.imgs)))
print("Test: " + str(len(test_data.imgs)))
# Out:
# Training: 24005
# Validation: 4000
# Test: 4000

# %%
real_data = load_real_datasets.SonarDescriptorRealDataset(None, None)

# %%
print("Real: " + str(len(real_data.imgs)))
# Out:
# Real: 2182

# %%
functions.plot_train_data(train_data)

# %%
functions.plot_data(val_data)

# %%
functions.plot_data(test_data)

# %%
functions.plot_data(real_data)

# %%
q_pose = real_data.poses[700]

q_x, q_y, q_Y_deg = q_pose
q_pose = imports.np.array([q_x, q_y, (90+q_Y_deg)%360])

gt_pose_idx = train_data.gtquery(q_x, q_y, q_Y_deg)

# %%
functions.plot_synth_poses_train(train_data, "blue")
functions.plot_synth_poses_val(val_data, "red")

print("Validation pre filtering: " + str(len(val_data.imgs)))
# Out:
# Validation pre filtering: 4000

# %%
functions.filter_data(train_data, val_data)

functions.plot_synth_poses_train(train_data, "blue")
functions.plot_synth_poses_val(val_data, "red")

print("Validation post filtering: " + str(len(val_data.imgs)))
# Out:
# Filtering validation poses: 100%|█████████| 4000/4000 [00:01<00:00, 2064.62it/s]
# Validation post filtering: 3253

# %%
functions.plot_synth_poses_train(train_data, "blue")
functions.plot_synth_poses_val(test_data, "red")

print("Test pre filtering: " + str(len(test_data.imgs)))
# Out:
# Test pre filtering: 4000

# %%
functions.filter_data(train_data, test_data)

functions.plot_synth_poses_train(train_data, "blue")
functions.plot_synth_poses_val(test_data, "red")

print("Test post filtering: " + str(len(test_data.imgs)))
# Out:
# Filtering validation poses: 100%|█████████| 4000/4000 [00:01<00:00, 2082.36it/s]
# Test post filtering: 3271

# %%
functions.localization(train_data, val_data, real_data)
# Out:
# iou: 0.9454411199809766
# yaw difference tensor(4.1440) deg
# localization error:  0.088764995 meters

# %%
batch = 16
train_dataloader = imports.DataLoader(train_data, batch_size=batch, shuffle=True)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model instantiation

# %%
net = model_classes.Model().cuda()
net.train()

optimizer = imports.torch.optim.AdamW(net.parameters(), lr = 0.01)
scheduler = imports.torch.optim.lr_scheduler.StepLR(optimizer, step_size=len(train_data), gamma=0.8)

drop = imports.torch.nn.Dropout(0.3).cuda()

# %%
locacriterion = imports.torch.nn.CrossEntropyLoss().cuda()
recocriterion = imports.torch.nn.MSELoss().cuda()

# %% [markdown]
# ## Training Pipeline

# %% [markdown]
# ### Train epochs

# %%
train_epochs.train_epochs(writer, train_data, train_dataloader, net, optimizer, scheduler, drop, recocriterion, locacriterion)
# Out:
#   1%|▍                                        | 18/1501 [00:18<25:21,  1.03s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 train_epochs.train_epochs(writer, train_data, train_dataloader, net, optimizer, scheduler, drop, recocriterion, locacriterion)
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Training/train_epochs.py:39, in train_epochs(writer, train_data, train_dataloader, net, optimizer, scheduler, drop, recocriterion, locacriterion)
#      36     scheduler.step()
#      37     train_losses.append(loss.item())
# ---> 39     imports.torch.cuda.empty_cache()
#      41 print("train loss mean:", imports.np.array(train_losses).mean())
#      43 model_classes.save_state(epoch, net, f"correct_model_3/epoch_{str(epoch).zfill(2)}.pth")
#
# File ~/.local/lib/python3.10/site-packages/torch/cuda/memory.py:218, in empty_cache()
#     207 r"""Release all unoccupied cached memory currently held by the caching
#     208 allocator so that those can be used in other GPU application and visible in
#     209 `nvidia-smi`.
#    (...)
#     215     more details about GPU memory management.
#     216 """
#     217 if is_initialized():
# --> 218     torch._C._cuda_emptyCache()
#
# KeyboardInterrupt:

# %%
training_functions.get_descriptors(train_data, val_data, net)
# Out:
#   2%|▌                                      | 362/24005 [00:03<04:18, 91.41it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 training_functions.get_descriptors(train_data, val_data, net)
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Training/functions.py:80, in get_descriptors(train_data, val_data, net)
#      78     image, _, _, _, _, _ = train_data[idx]
#      79     image = image[None].cuda()
# ---> 80     descriptor = net(image, reco=False)[0, :].detach().cpu()
#      81     train_pred_embeds[idx, :] = descriptor
#      82 train_data.computeDescriptors(net)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:295, in Model.forward(self, x, reco)
#     294 def forward(self, x, reco=False):
# --> 295     out = self.encoder(x)
#     296     embed= imports.torch.nn.functional.normalize(self.embed(out[-1]).flatten(1), p=2, dim=1)
#     298     if reco:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:211, in PyramidVisionTransformer.forward(self, x)
#     210 def forward(self, x):
# --> 211     x = self.forward_features(x)
#     213     if self.F4:
#     214         x = x[3:4]
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:204, in PyramidVisionTransformer.forward_features(self, x)
#     202 x = pos_drop(x + pos_embed)
#     203 for blk in block:
# --> 204     x = blk(x, H, W)
#     205 x = x.reshape(B, H, W, -1).permute(0, 3, 1, 2).contiguous()
#     206 outs.append(x)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:101, in Block.forward(self, x, H, W)
#      99 def forward(self, x, H, W):
#     100     x = x + self.drop_path(self.attn(self.norm1(x), H, W))
# --> 101     x = x + self.drop_path(self.mlp(self.norm2(x)))
#     103     return x
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:34, in Mlp.forward(self, x)
#      32 x = self.act(x)
#      33 x = self.drop(x)
# ---> 34 x = self.fc2(x)
#      35 x = self.drop(x)
#      36 return x
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualize Training results on Validation data

# %% [markdown]
# ### Load the checkpoint model

# %%
checkpoint_path = f"correct_model_3/epoch_24.pth"
net = model_classes.Model()
model_classes.load_state(net, checkpoint_path)
net = net.cuda()
net.eval();

# %% [markdown]
# ### Compute the final descriptors of the training data

# %% [markdown]
# ### Query the database

# %%
train_data.apply_random_rot = False
train_data.computeDescriptors(net)
# Out:
# computing dataset descriptors
#   1%|▎                                      | 174/24005 [00:01<04:13, 93.95it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 2
#       1 train_data.apply_random_rot = False
# ----> 2 train_data.computeDescriptors(net)
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Dataloader/load_datasets.py:102, in SonarDescriptorDatasetFull.computeDescriptors(self, net)
#     100         sin, cos = imports.torch.sin(image_), imports.torch.cos(image_)
#     101         image_ = imports.torch.cat([sin, cos]).cuda()[None]
# --> 102         descriptor = net(image_, reco=False)[0, :].detach().cpu().numpy()
#     103         self.descriptors.append(descriptor)
#     104 print("descriptors computed!")
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:295, in Model.forward(self, x, reco)
#     294 def forward(self, x, reco=False):
# --> 295     out = self.encoder(x)
#     296     embed= imports.torch.nn.functional.normalize(self.embed(out[-1]).flatten(1), p=2, dim=1)
#     298     if reco:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:211, in PyramidVisionTransformer.forward(self, x)
#     210 def forward(self, x):
# --> 211     x = self.forward_features(x)
#     213     if self.F4:
#     214         x = x[3:4]
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:204, in PyramidVisionTransformer.forward_features(self, x)
#     202 x = pos_drop(x + pos_embed)
#     203 for blk in block:
# --> 204     x = blk(x, H, W)
#     205 x = x.reshape(B, H, W, -1).permute(0, 3, 1, 2).contiguous()
#     206 outs.append(x)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:101, in Block.forward(self, x, H, W)
#      99 def forward(self, x, H, W):
#     100     x = x + self.drop_path(self.attn(self.norm1(x), H, W))
# --> 101     x = x + self.drop_path(self.mlp(self.norm2(x)))
#     103     return x
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1915, in Module.__getattr__(self, name)
#    1910         self._backward_pre_hooks = OrderedDict()
#    1912 # It is crucial that the return type is not annotated as `Any`, otherwise type checking
#    1913 # on `torch.nn.Module` and all its subclasses is largely disabled as a result. See:
#    1914 # https://github.com/pytorch/pytorch/pull/115074
# -> 1915 def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#    1916     if "_parameters" in self.__dict__:
#    1917         _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:

# %%
val_data.computeDescriptors(net)
# Out:
# computing dataset descriptors
#   5%|█▉                                      | 156/3253 [00:01<00:34, 88.98it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 val_data.computeDescriptors(net)
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Dataloader/load_datasets.py:100, in SonarDescriptorDatasetFull.computeDescriptors(self, net)
#      98 image_ = ( image_ / 255.0 ) - 0.5
#      99 image_ = image_[None] * imports.np.pi
# --> 100 sin, cos = imports.torch.sin(image_), imports.torch.cos(image_)
#     101 image_ = imports.torch.cat([sin, cos]).cuda()[None]
#     102 descriptor = net(image_, reco=False)[0, :].detach().cpu().numpy()
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualize query results: sonar images

# %%
import pickle

with open("train_data.pickle", "wb") as handle:
    pickle.dump(train_data, handle)

# %%
visualize_results.analyze_feature_robustness(train_data, net)
# Out:
# torch.Size([1, 16, 64, 64]) tensor(-11.2580, device='cuda:0', grad_fn=<MinBackward1>) tensor(10.9705, device='cuda:0', grad_fn=<MaxBackward1>)
# torch.Size([1, 32, 32, 32]) tensor(-43.4682, device='cuda:0', grad_fn=<MinBackward1>) tensor(45.2391, device='cuda:0', grad_fn=<MaxBackward1>)
# torch.Size([1, 64, 16, 16]) tensor(-23.6651, device='cuda:0', grad_fn=<MinBackward1>) tensor(25.0088, device='cuda:0', grad_fn=<MaxBackward1>)
# torch.Size([1, 128, 8, 8]) tensor(-12.7368, device='cuda:0', grad_fn=<MinBackward1>) tensor(15.7262, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(-0.5514, device='cuda:0', grad_fn=<MinBackward1>) tensor(0.5814, device='cuda:0', grad_fn=<MaxBackward1>)

# %%
query_idx = imports.random.randint(0, len(val_data))

loca_error, orie_error = visualize_results.process(query_idx, net, train_data, val_data, plot=True)
print(f"localization error: {loca_error:6.4f} meters")
print(f"orientation error : {orie_error:6.4f} degrees")
# Out:
# iou: 0.0
# localization error: 11.6297 meters
# orientation error : 91.0809 degrees

# %%
loca_errors, orie_errors = [], []

for query_idx in imports.tqdm(range(0, len(val_data))):
    loca_error, orie_error = visualize_results.process(query_idx, net, train_data, val_data, plot=False)
    loca_errors.append(loca_error)
    orie_errors.append(orie_error)

avg_loca_error = imports.np.array(loca_errors).mean()
avg_orie_error = imports.np.array(orie_errors).mean()

print(f"average localization error: {avg_loca_error:6.4f} meters")
print(f"average orientation error : {avg_orie_error:6.4f} degrees")
# Out:
#   2%|█                                        | 81/3253 [00:02<01:25, 36.90it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 4
#       1 loca_errors, orie_errors = [], []
#       3 for query_idx in imports.tqdm(range(0, len(val_data))):
# ----> 4     loca_error, orie_error = visualize_results.process(query_idx, net, train_data, val_data, plot=False)
#       5     loca_errors.append(loca_error)
#       6     orie_errors.append(orie_error)
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Training/visualize_results.py:19, in process(q_idx, net, train_data, val_data, plot)
#      16     q_desc = net(q_image_a, reco=False)[0, :]
#      17 q_desc = q_desc.detach().cpu().numpy()
# ---> 19 q_x, q_y, q_Y, q_Y_deg = functions.parse_pose(q_pose)
#      20 if plot:
#      21     functions.scatter_point(q_x, q_y, 'magenta', label="val pose (query)")
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Dataloader/functions.py:18, in parse_pose(pose)
#      15 def plot_synth_poses_val(vd, color="red"):
#      16     imports.plt.scatter(vd.poses[:, 0], vd.poses[:, 1], c=color, marker='o', linestyle='None', s = 1)
# ---> 18 def parse_pose(pose):
#      19     x, y, Y_deg = imports.np.array(pose, copy=True)
#      20     #Y_deg = 90 + Y_deg
#
# KeyboardInterrupt:

# %%
loca_errors = imports.np.array(loca_errors)
orie_errors = imports.np.array(orie_errors)

# %%
loca_errors.argmax()
# Out:
# np.int64(1321)

# %%
le = loca_errors[loca_errors<10]
oe = orie_errors[loca_errors<10]
print(le.mean())
print(oe.mean())
# Out:
# 5.391367
# 43.923233

# %% [markdown]
# ## Visualize Training results on Test data

# %% [markdown]
# ### Load the checkpoint model

# %%
checkpoint_path = f"correct_model_3/epoch_24.pth"
net = model_classes.Model()
model_classes.load_state(net, checkpoint_path)
net = net.cuda()
net.eval();

# %% [markdown]
# ### Compute the final descriptors of the training data

# %% [markdown]
# ### Query the database

# %%
train_data.apply_random_rot = False
train_data.computeDescriptors(net)
# Out:
# computing dataset descriptors
#   0%|▏                                      | 108/24005 [00:01<04:24, 90.19it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 2
#       1 train_data.apply_random_rot = False
# ----> 2 train_data.computeDescriptors(net)
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Dataloader/load_datasets.py:102, in SonarDescriptorDatasetFull.computeDescriptors(self, net)
#     100         sin, cos = imports.torch.sin(image_), imports.torch.cos(image_)
#     101         image_ = imports.torch.cat([sin, cos]).cuda()[None]
# --> 102         descriptor = net(image_, reco=False)[0, :].detach().cpu().numpy()
#     103         self.descriptors.append(descriptor)
#     104 print("descriptors computed!")
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:295, in Model.forward(self, x, reco)
#     294 def forward(self, x, reco=False):
# --> 295     out = self.encoder(x)
#     296     embed= imports.torch.nn.functional.normalize(self.embed(out[-1]).flatten(1), p=2, dim=1)
#     298     if reco:
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:211, in PyramidVisionTransformer.forward(self, x)
#     210 def forward(self, x):
# --> 211     x = self.forward_features(x)
#     213     if self.F4:
#     214         x = x[3:4]
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:204, in PyramidVisionTransformer.forward_features(self, x)
#     202 x = pos_drop(x + pos_embed)
#     203 for blk in block:
# --> 204     x = blk(x, H, W)
#     205 x = x.reshape(B, H, W, -1).permute(0, 3, 1, 2).contiguous()
#     206 outs.append(x)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:100, in Block.forward(self, x, H, W)
#      99 def forward(self, x, H, W):
# --> 100     x = x + self.drop_path(self.attn(self.norm1(x), H, W))
#     101     x = x + self.drop_path(self.mlp(self.norm2(x)))
#     103     return x
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Model/model_classes.py:70, in Attention.forward(self, x, H, W)
#      68     kv = self.kv(x_).reshape(B, -1, 2, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
#      69 else:
# ---> 70     kv = self.kv(x).reshape(B, -1, 2, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
#      71 k, v = kv[0], kv[1]
#      73 attn = (q @ k.transpose(-2, -1)) * self.scale
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualize query results: sonar images

# %%
import pickle

with open("train_data.pickle", "wb") as handle:
    pickle.dump(train_data, handle)

# %%
visualize_results.analyze_feature_robustness(train_data, net)
# Out:
# torch.Size([1, 16, 64, 64]) tensor(-11.2580, device='cuda:0', grad_fn=<MinBackward1>) tensor(10.9705, device='cuda:0', grad_fn=<MaxBackward1>)
# torch.Size([1, 32, 32, 32]) tensor(-43.4682, device='cuda:0', grad_fn=<MinBackward1>) tensor(45.2391, device='cuda:0', grad_fn=<MaxBackward1>)
# torch.Size([1, 64, 16, 16]) tensor(-23.6651, device='cuda:0', grad_fn=<MinBackward1>) tensor(25.0088, device='cuda:0', grad_fn=<MaxBackward1>)
# torch.Size([1, 128, 8, 8]) tensor(-12.7368, device='cuda:0', grad_fn=<MinBackward1>) tensor(15.7262, device='cuda:0', grad_fn=<MaxBackward1>)
# tensor(-0.5549, device='cuda:0', grad_fn=<MinBackward1>) tensor(0.5747, device='cuda:0', grad_fn=<MaxBackward1>)

# %%
query_idx = imports.random.randint(0, len(test_data))

loca_error, orie_error = visualize_results.process(query_idx, net, train_data, test_data, plot=True)
print(f"localization error: {loca_error:6.4f} meters")
print(f"orientation error : {orie_error:6.4f} degrees")
# Out:
# iou: 0.5080352454179221
# localization error: 4.4230 meters
# orientation error : 84.9395 degrees

# %%
loca_errors, orie_errors = [], []

for query_idx in imports.tqdm(range(0, len(test_data))):
    loca_error, orie_error = visualize_results.process(query_idx, net, train_data, test_data, plot=False)
    loca_errors.append(loca_error)
    orie_errors.append(orie_error)

avg_loca_error = np.array(loca_errors).mean()
avg_orie_error = np.array(orie_errors).mean()

print(f"average localization error: {avg_loca_error:6.4f} meters")
print(f"average orientation error : {avg_orie_error:6.4f} degrees")
# Out:
#   1%|▌                                        | 48/3271 [00:01<01:24, 38.11it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 4
#       1 loca_errors, orie_errors = [], []
#       3 for query_idx in imports.tqdm(range(0, len(test_data))):
# ----> 4     loca_error, orie_error = visualize_results.process(query_idx, net, train_data, test_data, plot=False)
#       5     loca_errors.append(loca_error)
#       6     orie_errors.append(orie_error)
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Training/visualize_results.py:52, in process(q_idx, net, train_data, val_data, plot)
#      49 orie_error = gt_Y_deg - min_Y_deg.item()
#      50 orie_error = imports.np.abs((orie_error + 180) % 360 - 180)
# ---> 52 gt_closest_image = train_data[val_data.closest_indices[q_idx]][1]
#      54 if plot:
#      55     imports.plt.imshow(mask3, cmap="gray")
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Dataloader/load_datasets.py:158, in SonarDescriptorDatasetFull.__getitem__(self, idx)
#     154 pose = imports.np.copy(self.poses[idx])
#     156 image = imports.cv2.resize(image, self.img_size)
# --> 158 image = self.pad(imports.torch.Tensor(image))
#     159 image = imports.torch.Tensor(image)
#     160 image = (image / 255.0) - 0.5
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/modules/padding.py:215, in _ConstantPadNd.forward(self, input)
#     214 def forward(self, input: Tensor) -> Tensor:
# --> 215     return F.pad(input, self.padding, "constant", self.value)
#
# File ~/.local/lib/python3.10/site-packages/torch/nn/functional.py:5209, in pad(input, pad, mode, value)
#    5202         if mode == "replicate":
#    5203             # Use slow decomp whose backward will be in terms of index_put.
#    5204             # importlib is required because the import cannot be top level
#    5205             # (cycle) and cannot be nested (TS doesn't support)
#    5206             return importlib.import_module(
#    5207                 "torch._decomp.decompositions"
#    5208             )._replication_pad(input, pad)
# -> 5209 return torch._C._nn.pad(input, pad, mode, value)
#
# KeyboardInterrupt:

# %%
loca_errors = imports.np.array(loca_errors)
orie_errors = imports.np.array(orie_errors)

# %%
loca_errors.argmax()
# Out:
# np.int64(24)

# %%
le = loca_errors[loca_errors<10]
oe = orie_errors[loca_errors<10]
print(le.mean())
print(oe.mean())
# Out:
# 4.7176623
# 36.883026

# %% [markdown]
# ## process real images

# %%
query_idx = imports.random.randint(0, 600)
train_data.apply_random_rot = True
train_data.training = True
print("query_idx:", query_idx)
real_functions.process_real(query_idx, net, train_data, real_data)
# Out:
# query_idx: 432
# 266.44012 205.10986 1.8072953 -76.44961
# iou: 0.6388185041832116
# localization error Upper:  3.45032 meters

# %% [markdown]
# ## Process ONLY real images

# %%
real_data_train = load_only_real.SonarDescriptorOnlyRealDataset()
real_data_valid = load_only_real.SonarDescriptorOnlyRealDataset(real_data_train)

# %%
real_data_train.computeDescriptors(net)
# Out:
# computing dataset descriptors
# 100%|█████████████████████████████████████████| 710/710 [00:08<00:00, 83.24it/s]
# descriptors computed!

# %%
real_functions.visualize_real(train_data, real_data)

# %%
query_idx = imports.random.randint(700, len(real_data_valid))
loca_error, orie_error = real_functions.process_only_real(query_idx, net, real_data_train, real_data_valid, plot=True)
print(f"localization error: {loca_error:6.4f} meters")
print(f"orientation error : {orie_error:6.4f} degrees")
# Out:
# iou: 0.008860578577689335
# localization error: 9.5560 meters
# orientation error : 44.5360 degrees

# %%
loca_errors, orie_errors = [], []

for query_idx in imports.tqdm(range(0, len(real_data_valid))):
    loca_error, orie_error = real_functions.process_only_real(query_idx, net, real_data_train, real_data_valid, plot=False)
    loca_errors.append(loca_error)
    orie_errors.append(orie_error)

avg_loca_error = imports.np.array(loca_errors).mean()
avg_orie_error = imports.np.abs(np.array(orie_errors)).mean()

print(f"average localization error: {avg_loca_error:6.4f} meters")
print(f"average orientation error : {avg_orie_error:6.4f} degrees")
# Out:
#  20%|████████▏                                | 156/785 [00:04<00:17, 36.64it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 4
#       1 loca_errors, orie_errors = [], []
#       3 for query_idx in imports.tqdm(range(0, len(real_data_valid))):
# ----> 4     loca_error, orie_error = real_functions.process_only_real(query_idx, net, real_data_train, real_data_valid, plot=False)
#       5     loca_errors.append(loca_error)
#       6     orie_errors.append(orie_error)
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Real/functions.py:104, in process_only_real(q_idx, net, train_data, val_data, plot)
#     101     scatter_real_orientation(q_x, q_y, q_Y, "magenta")
#     103 minidx = train_data.query(q_desc)
# --> 104 _, min_img, min_pose, min_img_path, min_lab_path = train_data[minidx]
#     106 min_x, min_y, min_Y_deg = min_pose
#     107 min_Y_deg = (90+min_Y_deg)%360
#
# File ~/Desktop/Notebook_bsd/Classes_and_functions/Real/load_only_real.py:102, in SonarDescriptorOnlyRealDataset.__getitem__(self, idx)
#      99 def __getitem__(self, idx):
#     101     img_path = self.imgs[idx]
# --> 102     image = imports.cv2.cvtColor(imports.cv2.imread(img_path), imports.cv2.COLOR_BGR2GRAY)
#     103     pose = imports.np.copy(self.poses[idx])
#     104     image = imports.cv2.resize(image, self.img_size)
#
# KeyboardInterrupt:

# %%
avg_orie_error.min()
# Out:
# np.float32(88.72866)

# %% [markdown]
# ## K-TOP

# %%
K = 15
bests = database.norms.argsort()

preds = np.zeros((K, 2))
imgs = []
for i in range(K):
    _, img, minpos, _, _, _ = database.dataset[bests[i]]
    preds[i, :] = minpos[:2]
    imgs.append(img)

colors = []
for v in database.norms/database.norms.max():
    colors.append([v, 0, 0])
    
plt.scatter(train_data.poses[:train_data.synth, 0], train_data.poses[:train_data.synth, 1], c=colors, marker='o', linestyle='None', s = 1)
plt.scatter(query_gtpose[0].item(), query_gtpose[1].item(), c='green',s = 20.51, label="gt query pose")
plt.scatter(preds[:, 0], preds[:, 1], c='blue', s = 20.51, label=f"database predicted {K} closest poses")
plt.legend(loc="lower right")

plt.figure()

f, axarr = plt.subplots(K, 2, figsize=(20, 20))

axarr[0,0].set_title(f"query image")
axarr[0,1].set_title(f"retrieved image")


for i in range(K):

    axarr[i,0].imshow(query_real_image.detach().cpu().numpy()[0, :, :], cmap='gray')
    axarr[i,1].imshow(imgs[i].numpy()[0, :, :], cmap='gray')
